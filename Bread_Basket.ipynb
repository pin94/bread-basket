# %% [markdown]
# <a href="https://colab.research.google.com/github/pin94/bread-basket/blob/main/Bread_Basket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Database

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
myDirFiles='/content/drive/MyDrive/BreadBasket_DMS.csv'
df=pd.read_csv(myDirFiles,delimiter=',')
df
# Out:
#              Date      Time  Transaction           Item
# 0      2016-10-30  09:58:11            1          Bread
# 1      2016-10-30  10:05:34            2   Scandinavian
# 2      2016-10-30  10:05:34            2   Scandinavian
# 3      2016-10-30  10:07:57            3  Hot chocolate
# 4      2016-10-30  10:07:57            3            Jam
# ...           ...       ...          ...            ...
# 21288  2017-04-09  14:32:58         9682         Coffee
# 21289  2017-04-09  14:32:58         9682            Tea
# 21290  2017-04-09  14:57:06         9683         Coffee
# 21291  2017-04-09  14:57:06         9683         Pastry
# 21292  2017-04-09  15:04:24         9684      Smoothies
#
# [21293 rows x 4 columns]

# %% [markdown]
# # Describe

# %%
df.describe()
# Out:
#         Transaction
# count  21293.000000
# mean    4951.990889
# std     2787.758400
# min        1.000000
# 25%     2548.000000
# 50%     5067.000000
# 75%     7329.000000
# max     9684.000000

# %%
df.rename(columns={'Transaction':'Transaction ID'},inplace=True)
df.head()
# Out:
#          Date      Time  Transaction ID           Item
# 0  2016-10-30  09:58:11               1          Bread
# 1  2016-10-30  10:05:34               2   Scandinavian
# 2  2016-10-30  10:05:34               2   Scandinavian
# 3  2016-10-30  10:07:57               3  Hot chocolate
# 4  2016-10-30  10:07:57               3            Jam

# %% [markdown]
# # Value Counts

# %%
df.Item.value_counts()
# Out:
# Coffee            5471
# Bread             3325
# Tea               1435
# Cake              1025
# Pastry             856
#                   ...
# Chicken sand         1
# The BART             1
# Adjustment           1
# Olum & polenta       1
# Bacon                1
# Name: Item, Length: 95, dtype: int64

# %% [markdown]
# # Cleaning Database

# %%
df.Item.unique()
# Out:
# array(['Bread', 'Scandinavian', 'Hot chocolate', 'Jam', 'Cookies',
#        'Muffin', 'Coffee', 'Pastry', 'Medialuna', 'Tea', 'NONE',
#        'Tartine', 'Basket', 'Mineral water', 'Farm House', 'Fudge',
#        'Juice', "Ella's Kitchen Pouches", 'Victorian Sponge', 'Frittata',
#        'Hearty & Seasonal', 'Soup', 'Pick and Mix Bowls', 'Smoothies',
#        'Cake', 'Mighty Protein', 'Chicken sand', 'Coke',
#        'My-5 Fruit Shoot', 'Focaccia', 'Sandwich', 'Alfajores', 'Eggs',
#        'Brownie', 'Dulce de Leche', 'Honey', 'The BART', 'Granola',
#        'Fairy Doors', 'Empanadas', 'Keeping It Local', 'Art Tray',
#        'Bowl Nic Pitt', 'Bread Pudding', 'Adjustment', 'Truffles',
#        'Chimichurri Oil', 'Bacon', 'Spread', 'Kids biscuit', 'Siblings',
#        'Caramel bites', 'Jammie Dodgers', 'Tiffin', 'Olum & polenta',
#        'Polenta', 'The Nomad', 'Hack the stack', 'Bakewell',
#        'Lemon and coconut', 'Toast', 'Scone', 'Crepes', 'Vegan mincepie',
# ...

# %%
df=df[df.Item!='Adjustment']

# %%
df=df[df.Item!='NONE']

# %%
df.Item.unique()
# Out:
# array(['Bread', 'Scandinavian', 'Hot chocolate', 'Jam', 'Cookies',
#        'Muffin', 'Coffee', 'Pastry', 'Medialuna', 'Tea', 'Tartine',
#        'Basket', 'Mineral water', 'Farm House', 'Fudge', 'Juice',
#        "Ella's Kitchen Pouches", 'Victorian Sponge', 'Frittata',
#        'Hearty & Seasonal', 'Soup', 'Pick and Mix Bowls', 'Smoothies',
#        'Cake', 'Mighty Protein', 'Chicken sand', 'Coke',
#        'My-5 Fruit Shoot', 'Focaccia', 'Sandwich', 'Alfajores', 'Eggs',
#        'Brownie', 'Dulce de Leche', 'Honey', 'The BART', 'Granola',
#        'Fairy Doors', 'Empanadas', 'Keeping It Local', 'Art Tray',
#        'Bowl Nic Pitt', 'Bread Pudding', 'Truffles', 'Chimichurri Oil',
#        'Bacon', 'Spread', 'Kids biscuit', 'Siblings', 'Caramel bites',
#        'Jammie Dodgers', 'Tiffin', 'Olum & polenta', 'Polenta',
#        'The Nomad', 'Hack the stack', 'Bakewell', 'Lemon and coconut',
#        'Toast', 'Scone', 'Crepes', 'Vegan mincepie', 'Bare Popcorn',
# ...

# %%
df.Date=pd.to_datetime(df.Date)
df.Date.astype
# Out:
# <bound method NDFrame.astype of 0       2016-10-30
# 1       2016-10-30
# 2       2016-10-30
# 3       2016-10-30
# 4       2016-10-30
#            ...
# 21288   2017-04-09
# 21289   2017-04-09
# 21290   2017-04-09
# 21291   2017-04-09
# 21292   2017-04-09
# Name: Date, Length: 20506, dtype: datetime64[ns]>

# %%
df['#Date']=df.Date.dt.day

# %%
df['Month']=df.Date.dt.month

# %%
df['Day']=df.Date.dt.day_name()

# %%
df['Year']=df.Date.dt.year

# %%
df.head()
# Out:
#         Date      Time  Transaction ID           Item  #Date  Month     Day  \
# 0 2016-10-30  09:58:11               1          Bread     30     10  Sunday
# 1 2016-10-30  10:05:34               2   Scandinavian     30     10  Sunday
# 2 2016-10-30  10:05:34               2   Scandinavian     30     10  Sunday
# 3 2016-10-30  10:07:57               3  Hot chocolate     30     10  Sunday
# 4 2016-10-30  10:07:57               3            Jam     30     10  Sunday
#
#    Year
# 0  2016
# 1  2016
# 2  2016
# 3  2016
# 4  2016

# %%
df.Year.value_counts()
# Out:
# 2017    12363
# 2016     8143
# Name: Year, dtype: int64

# %%
month={10:'Oct',11:'Nov',12:'Dec',1:'Jan',2:'Feb',3:'Mar',4:'Apr'}
b=df.Month

# %%
df.Month=b.map(month)
df.head()
# Out:
#         Date      Time  Transaction ID           Item  #Date Month     Day  \
# 0 2016-10-30  09:58:11               1          Bread     30   Oct  Sunday
# 1 2016-10-30  10:05:34               2   Scandinavian     30   Oct  Sunday
# 2 2016-10-30  10:05:34               2   Scandinavian     30   Oct  Sunday
# 3 2016-10-30  10:07:57               3  Hot chocolate     30   Oct  Sunday
# 4 2016-10-30  10:07:57               3            Jam     30   Oct  Sunday
#
#    Year
# 0  2016
# 1  2016
# 2  2016
# 3  2016
# 4  2016

# %%
df.groupby(['Month'])['Item'].value_counts()[:5].unstack()
# Out:
# Item   Coffee  Bread  Tea  Cake  Sandwich
# Month
# Apr       290    175   73    72        57

# %%
df.groupby(['Item'])['Month'].value_counts().unstack()
# Out:
# Month                      Apr   Dec    Feb   Jan   Mar    Nov  Oct
# Item
# Afternoon with the baker   2.0   NaN   13.0  15.0  14.0    NaN  NaN
# Alfajores                 24.0  45.0  112.0  39.0   8.0  141.0  NaN
# Argentina Night            5.0   NaN    NaN   NaN   2.0    NaN  NaN
# Art Tray                   1.0   6.0    5.0   5.0   3.0   18.0  NaN
# Bacon                      NaN   NaN    NaN   NaN   NaN    1.0  NaN
# ...                        ...   ...    ...   ...   ...    ...  ...
# Tshirt                     NaN   NaN   21.0   NaN   NaN    NaN  NaN
# Valentine's card           NaN   NaN   12.0   1.0   NaN    NaN  NaN
# Vegan Feast                7.0   NaN    3.0   NaN   6.0    NaN  NaN
# Vegan mincepie             NaN  33.0    5.0  13.0   3.0    NaN  NaN
# Victorian Sponge           NaN   NaN    NaN   NaN   NaN    4.0  3.0
#
# [93 rows x 7 columns]

# %%
df.groupby(['Item'])['Month'].value_counts().nlargest(5).unstack()
# Out:
# Month   Dec   Feb  Jan   Mar   Nov
# Item
# Coffee  932  1004  892  1071  1189

# %%
df.groupby(['Month'])['Item'].value_counts().nlargest(3).unstack()
# Out:
# Item   Coffee
# Month
# Feb      1004
# Mar      1071
# Nov      1189

# %% [markdown]
# # Create Graph

# %%
set_month = list(set(df.Month))
sort_month = sorted(set_month)
for i in range (len (sort_month)):
  month=df[df.Month==sort_month[i]]
  fig, ax = plt.subplots(1,2, figsize=(15,9))
  fig.suptitle('Products sold on ' + str(sort_month[i]), fontsize=20, fontweight='bold',y=1.02)
  month.Item.value_counts()[:10].plot(kind='barh',fontsize=12, ax=ax[0],color ='blue')
  month.Item.value_counts(ascending=True)[:10].plot(kind='barh',fontsize=12, ax=ax[1],color ='maroon')
  ax[0].set_title('10 Top', fontsize=18, fontweight='bold')
  ax[1].set_title('10 Bottom', fontsize=18, fontweight='bold')
  ax[0].set(xlabel='Values', ylabel = 'Item')
  ax[1].set(xlabel='Values', ylabel = 'Item')
  fig.tight_layout(pad=3, h_pad=3.0)

# %%
df.Time=pd.to_datetime(df.Time)

# %%
df['Hour']=df.Time.dt.hour

# %%
df.head()
# Out:
#         Date                Time  Transaction ID           Item  #Date Month  \
# 0 2016-10-30 2023-03-14 09:58:11               1          Bread     30   Oct
# 1 2016-10-30 2023-03-14 10:05:34               2   Scandinavian     30   Oct
# 2 2016-10-30 2023-03-14 10:05:34               2   Scandinavian     30   Oct
# 3 2016-10-30 2023-03-14 10:07:57               3  Hot chocolate     30   Oct
# 4 2016-10-30 2023-03-14 10:07:57               3            Jam     30   Oct
#
#       Day  Year  Hour
# 0  Sunday  2016     9
# 1  Sunday  2016    10
# 2  Sunday  2016    10
# 3  Sunday  2016    10
# 4  Sunday  2016    10

# %%
def section(hour):
  if hour >= 7 and hour < 11:
    section='Morning'
  elif hour >= 11 and hour <= 14:
    section='Afternoon'
  elif hour >= 14 and hour <=18:
    section='Evening'
  else:
    section='Night'
  return section

# %%
df['Section']=df.Hour.apply(section)
df.head()
# Out:
#         Date                Time  Transaction ID           Item  #Date Month  \
# 0 2016-10-30 2023-03-14 09:58:11               1          Bread     30   Oct
# 1 2016-10-30 2023-03-14 10:05:34               2   Scandinavian     30   Oct
# 2 2016-10-30 2023-03-14 10:05:34               2   Scandinavian     30   Oct
# 3 2016-10-30 2023-03-14 10:07:57               3  Hot chocolate     30   Oct
# 4 2016-10-30 2023-03-14 10:07:57               3            Jam     30   Oct
#
#       Day  Year  Hour  Section
# 0  Sunday  2016     9  Morning
# 1  Sunday  2016    10  Morning
# 2  Sunday  2016    10  Morning
# 3  Sunday  2016    10  Morning
# 4  Sunday  2016    10  Morning

# %%
df.Section.value_counts()
# Out:
# Afternoon    11213
# Morning       5301
# Evening       3908
# Night           84
# Name: Time, dtype: int64

# %%
morning=df[df.Section=='Morning']

# %%
morning.Item.value_counts().head()
# Out:
# Coffee       1615
# Bread        1081
# Pastry        453
# Medialuna     294
# Tea           280
# Name: Item, dtype: int64

# %%
hour=(list(set(df.Section)))

# %%
hour
# Out:
# ['Evening', 'Morning', 'Afternoon', 'Night']

# %%
for i in hour:
  print('Time section:',i)
  print(df[df.Section==i]['Item'].value_counts().head())
# Out:
# Time section: Evening
# Coffee           920
# Bread            558
# Tea              379
# Cake             328
# Hot chocolate    178
# Name: Item, dtype: int64
# Time section: Morning
# Coffee       1615
# Bread        1081
# Pastry        453
# Medialuna     294
# Tea           280
# Name: Item, dtype: int64
# Time section: Afternoon
# Coffee      2929
# Bread       1683
# Tea          773
# Sandwich     620
# Cake         566
# Name: Item, dtype: int64
# Time section: Night
# Tshirt         16
# Postcard       10
# Coffee          7
# Vegan Feast     7
# Coke            7
# Name: Item, dtype: int64

# %%
dfCust=df.drop_duplicates(subset=['Transaction ID'])
dfCust.head()
# Out:
#         Date                Time  Transaction ID           Item  #Date Month  \
# 0 2016-10-30 2023-03-14 09:58:11               1          Bread     30   Oct
# 1 2016-10-30 2023-03-14 10:05:34               2   Scandinavian     30   Oct
# 3 2016-10-30 2023-03-14 10:07:57               3  Hot chocolate     30   Oct
# 6 2016-10-30 2023-03-14 10:08:41               4         Muffin     30   Oct
# 7 2016-10-30 2023-03-14 10:13:03               5         Coffee     30   Oct
#
#       Day  Year  Hour  Section
# 0  Sunday  2016     9  Morning
# 1  Sunday  2016    10  Morning
# 3  Sunday  2016    10  Morning
# 6  Sunday  2016    10  Morning
# 7  Sunday  2016    10  Morning

# %%
df.Month.value_counts()
# Out:
# Nov    4435
# Mar    3944
# Feb    3906
# Jan    3356
# Dec    3339
# Apr    1157
# Oct     369
# Name: Month, dtype: int64
